# %% [markdown]
# ## Минимизация булевых функций методом карт Карно

# %%
from utils.karnaugh_map_solver import Solver

# %%
f = "not(x1) and x2 or x1 and not(x2) or x1 and x2"
solver = Solver(f)
solver.visualize_karnaugh_map()
solution = solver.solve()
print(solution)
# Out:
# f = x2 or x1

# %%
f = "not(x1) and x2 and x3 or x1 and x2 and x3 or x1 and not(x2) and not(x3) or x1 and not(x2) and x3"
solver = Solver(f)
solver.visualize_karnaugh_map()
solution = solver.solve()
print(solution)
# Out:
# f = x1 and not(x2) or x2 and x3

# %%
f = "not(x1) and not(x2) and not(x3) or not(x1) and not(x2) and x3 or not(x1) and x2 and x3 or x1 and not(x2) and not(x3) or x1 and not(x2) and not(x3) or x1 and not(x2) and x3 or x1 and x2 and x3"
solver = Solver(f)
solver.visualize_karnaugh_map()
solution = solver.solve()
print(solution)
# Out:
# f = x3 or not(x2)

# %%
f = "(x1 and x2 and not(x4)) or (x1 and x2 and x4) or (not(x1) and x3 and x5) or (not(x1) and x3 and not(x5)) or (x1 and not(x2) and x3)"
solver = Solver(f)
solver.visualize_karnaugh_map()
solution = solver.solve()
print(solution)
# Out:
# f = x3 or x1 and x2
